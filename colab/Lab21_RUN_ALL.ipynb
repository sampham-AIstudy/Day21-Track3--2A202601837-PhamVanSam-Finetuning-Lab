# %% [markdown]
# <a href="https://colab.research.google.com/github/sampham-AIstudy/Day21-Track3--2A202601837-PhamVanSam-Finetuning-Lab/blob/main/colab/Lab21_RUN_ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : Tesla T4
# VRAM   : 14.6 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 4.61s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "T4"        # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
#
# tier=T4  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=T4  model=unsloth/Qwen3.5-4B  max_length=1024
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 2.76k/2.76k [00:00<00:00, 8.84MB/s]
# tokenizer_config.json: 100% 15.7k/15.7k [00:00<00:00, 39.5MB/s]
# vocab.json: 100% 5.23M/5.23M [00:00<00:00, 68.2MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 82.4MB/s]
#
# tokenizer.json: downloading bytes:   6% 1.29M/20.0M [00:00<00:09, 2.02MB/s]
# tokenizer.json: downloading bytes: 100% 6.23M/6.23M [00:00<00:00, 8.84MB/s,  616kB/s  ]
# tokenizer.json: reconstructing file: 100% 20.0M/20.0M [00:00<00:00, 28.3MB/s, 1.98MB/s  ]
# added_tokens.json: 100% 904/904 [00:00<00:00, 4.80MB/s]
# special_tokens_map.json: 100% 876/876 [00:00<00:00, 6.51MB/s]
# chat_template.jinja: 100% 7.99k/7.99k [00:00<00:00, 28.1MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 1024. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 22s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=T4
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 76.2k/76.2k [00:00<00:00, 165MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files:   0% 0/2 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/5.33G [00:00<?, ?B/s]
# Downloading bytes:   1% 71.2M/9.32G [00:00<01:17, 120MB/s, 68.9MB/s  ]
# Downloading bytes:   4% 374M/9.32G [00:02<00:40, 219MB/s,  288MB/s  ]
# Downloading bytes:   5% 455M/9.32G [00:02<00:37, 239MB/s,  231MB/s  ]
# Downloading bytes:   7% 688M/9.32G [00:03<00:33, 254MB/s,  250MB/s  ]
# Downloading bytes:  10% 904M/9.32G [00:04<00:39, 213MB/s,  257MB/s  ]
# Downloading bytes:  16% 1.48G/9.32G [00:06<00:33, 237MB/s,  257MB/s  ]
# Downloading bytes:  24% 2.24G/9.32G [00:10<00:40, 174MB/s,  172MB/s  ]
# Downloading bytes:  34% 3.20G/9.32G [00:14<00:25, 241MB/s,  290MB/s  ]
# Downloading bytes:  38% 3.50G/9.32G [00:15<00:18, 307MB/s,  299MB/s  ]
# Downloading bytes:  41% 3.83G/9.32G [00:20<00:32, 169MB/s,  183MB/s  ]
# Downloading bytes:  43% 4.00G/9.32G [00:21<00:24, 216MB/s,  207MB/s  ]
# Reconstructing (incomplete total...):  24% 2.23G/9.32G [00:21<00:36, 195MB/s, 82.2MB/s  ]
# Downloading bytes:  48% 4.51G/9.32G [00:24<00:21, 220MB/s,  179MB/s  ]
# Reconstructing (incomplete total...):  27% 2.49G/9.32G [00:24<00:48, 142MB/s,  195MB/s  ]
# Downloading bytes:  49% 4.60G/9.32G [00:26<00:56, 83.0MB/s, 85.6MB/s  ]
# Downloading bytes:  55% 5.15G/9.32G [00:28<00:14, 288MB/s,  325MB/s  ]
# Downloading bytes:  57% 5.35G/9.32G [00:35<00:45, 86.9MB/s, 67.4MB/s  ]
# Downloading bytes:  62% 5.74G/9.32G [00:49<00:13, 269MB/s,  269MB/s  ]
# Reconstructing (incomplete total...):  39% 3.62G/9.32G [00:49<00:53, 106MB/s,  106MB/s  ]
# Downloading bytes:  63% 5.87G/9.32G [01:19<06:38, 8.66MB/s, 6.71MB/s  ]
# Downloading bytes:  66% 6.16G/9.32G [01:23<00:32, 97.3MB/s, 73.5MB/s  ]
# Downloading bytes:  68% 6.34G/9.32G [01:35<01:03, 46.6MB/s, 31.5MB/s  ]
# Downloading bytes:  70% 6.55G/9.32G [01:59<00:38, 72.6MB/s, 72.6MB/s  ]
# Reconstructing (incomplete total...):  49% 4.60G/9.32G [01:59<03:01, 26.0MB/s, 26.0MB/s  ]
# Downloading bytes:  71% 6.58G/9.32G [02:19<13:33, 3.37MB/s, 2.24MB/s  ]
# Downloading bytes:  74% 6.89G/9.32G [02:20<00:17, 136MB/s, 98.5MB/s  ]
# Downloading bytes:  77% 7.17G/9.32G [02:28<00:18, 117MB/s,  107MB/s  ]
# Downloading bytes:  79% 7.40G/9.32G [02:30<00:08, 221MB/s,  191MB/s  ]
# Downloading bytes:  81% 7.59G/9.32G [02:34<00:17, 98.5MB/s, 98.1MB/s  ]
# Downloading bytes:  83% 7.75G/9.32G [02:46<00:47, 33.4MB/s, 22.9MB/s  ]
# Downloading bytes:  86% 8.03G/9.32G [02:53<00:11, 114MB/s, 88.2MB/s  ]
# Reconstructing (incomplete total...):  70% 6.50G/9.32G [02:58<01:28, 31.7MB/s, 30.0MB/s  ]
# Downloading bytes:  86% 8.05G/9.32G [03:09<00:11, 114MB/s,  114MB/s  ]
# Reconstructing (incomplete total...):  72% 6.67G/9.32G [03:14<02:08, 20.6MB/s, 25.1MB/s  ]
# Reconstructing (incomplete total...):  76% 7.06G/9.32G [03:15<00:55, 40.6MB/s, 20.6MB/s  ]
# Reconstructing (incomplete total...):  76% 7.06G/9.32G [03:29<00:55, 40.6MB/s, 40.6MB/s  ]
# Reconstructing (incomplete total...):  80% 7.48G/9.32G [03:49<01:31, 20.1MB/s, 40.6MB/s  ]
# Reconstructing (incomplete total...):  87% 8.14G/9.32G [03:55<00:34, 33.8MB/s, 20.1MB/s  ]
# Reconstructing (incomplete total...):  89% 8.32G/9.32G [03:56<00:25, 39.7MB/s, 33.8MB/s  ]
# Reconstructing (incomplete total...):  91% 8.48G/9.32G [04:08<00:27, 29.9MB/s, 39.7MB/s  ]
#
# Fetching 2 files:  50% 1/2 [04:09<04:09, 249.17s/it]
# Reconstructing (incomplete total...):  94% 8.78G/9.32G [04:09<00:13, 40.8MB/s, 29.9MB/s  ]
# Reconstructing (incomplete total...):  97% 9.05G/9.32G [04:10<00:04, 54.0MB/s, 40.8MB/s  ]
# Reconstructing (incomplete total...):  99% 9.22G/9.32G [04:12<00:01, 59.5MB/s, 54.0MB/s  ]
# Reconstructing (incomplete total...): 100% 9.32G/9.32G [04:12<00:00, 67.4MB/s, 59.5MB/s  ]
#
# Fetching 2 files: 100% 2/2 [04:12<00:00, 126.26s/it]
# Download complete: 100% 8.05G/8.05G [04:12<00:00, 114MB/s,  114MB/s  ]
# Download complete: 100% 8.05G/8.05G [04:12<00:00, 31.9MB/s,  114MB/s  ]
# Reconstruction complete: 100% 9.32G/9.32G [04:12<00:00, 36.9MB/s, 67.4MB/s  ]
# Loading weights: 100% 426/426 [00:30<00:00, 13.75it/s]
#   [(a) base + naive prompt/target] batch 1/2     14s elapsed  ~   14s left
#   [(a) base + naive prompt/target] batch 2/2     27s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 27s
#   [(a) base + naive prompt/regression] batch 1/2      6s elapsed  ~    6s left
#   [(a) base + naive prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 13s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  3326ms
#   [(b) base + optimized prompt/target] batch 1/2      4s elapsed  ~    4s left
#   [(b) base + optimized prompt/target] batch 2/2      8s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 8s
#   [(b) base + optimized prompt/regression] batch 1/2      5s elapsed  ~    5s left
#   [(b) base + optimized prompt/regression] batch 2/2     12s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 12s
# (b) base + optimized prompt  target=0.688  regression=0.750  format=1.000  1017ms
# {
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 3325.7257312500033,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.6875,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 1016.6241018749957,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 359s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# T4 · unsloth/Qwen3.5-4B · all-linear · r=16 · LR 10x · 16-bit
# Tesla T4 (cuda, sm_75, 14.6 GB) -> precision=fp16
#   note: this GPU predates Ampere, so it has NO bfloat16. Using fp16 with gradient scaling instead. Tutorials that hardcode bf16=True fail here.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1044.01it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.29it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 32.46 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 32464896}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 1835008}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 283, 'trainable': 32456704}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "1024",
#   "per_device_train_batch_size": "1",
#   "gradient_accumulation_steps": "16",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "False",
#   "fp16": "True",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 5877.45 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 36090.04 examples/s]
# precision fix: {'precision': 'fp16', 'recast': 0, 'trainable_tensors': 496}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '1.381', 'grad_norm': '2.498', 'learning_rate': '8.83e-05', 'entropy': '1.032', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7699', 'epoch': '0.7111'}
# {'loss': '0.138', 'grad_norm': '0.5747', 'learning_rate': '6.434e-05', 'entropy': '0.2661', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9598', 'epoch': '1'}
# {'loss': '0.02883', 'grad_norm': '1.033', 'learning_rate': '3.566e-05', 'entropy': '0.04005', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9867', 'epoch': '1.356'}
# {'loss': '0.01709', 'grad_norm': '0.304', 'learning_rate': '1.17e-05', 'entropy': '0.0227', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9936', 'epoch': '1.711'}
# {'loss': '0.02675', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.01625', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9961', 'epoch': '2'}
# {'train_runtime': '962.1', 'train_samples_per_second': '0.468', 'train_steps_per_second': '0.031', 'train_loss': '0.6258', 'epoch': '2'}
# 100% 30/30 [16:02<00:00, 32.07s/it]
# train 963s  final loss 0.6258
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "T4",
#   "model": "unsloth/Qwen3.5-4B",
#   "precision": "fp16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 32464896,
#   "train_seconds": 962.6,
#   "peak_vram_gb": 12.01,
#   "final_loss": 0.6258,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 1026s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 920.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.41it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 32464896 |
# | attn-only(q,v) | 2 | 16 | 1835008 |
# | attn-only(q,v) matched | 2 | 283 | 32456704 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1042.71it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.37it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=283 (alpha=566)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 7681.63 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 41939.31 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': '5.749', 'learning_rate': '9.966e-05', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '0.8269', 'grad_norm': '1.843', 'learning_rate': '8.83e-05', 'entropy': '0.9397', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.8406', 'epoch': '0.7111'}
# {'loss': '0.148', 'grad_norm': '1.439', 'learning_rate': '6.434e-05', 'entropy': '0.2863', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.958', 'epoch': '1'}
# {'loss': '0.03869', 'grad_norm': '0.8716', 'learning_rate': '3.566e-05', 'entropy': '0.065', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.987', 'epoch': '1.356'}
# {'loss': '0.02185', 'grad_norm': '0.2212', 'learning_rate': '1.17e-05', 'entropy': '0.03137', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9912', 'epoch': '1.711'}
# {'loss': '0.02572', 'grad_norm': 'nan', 'learning_rate': '3.381e-07', 'entropy': '0.02246', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.995', 'epoch': '2'}
# {'train_runtime': '819.3', 'train_samples_per_second': '0.586', 'train_steps_per_second': '0.037', 'train_loss': '0.5374', 'epoch': '2'}
# 100% 30/30 [13:39<00:00, 27.31s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 2 files: 100% 2/2 [00:00<00:00, 1210.65it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 426/426 [00:34<00:00, 12.37it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 8031.78 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 45425.68 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248055}.
# {'loss': '2.163', 'grad_norm': 'nan', 'learning_rate': '9.966e-06', 'entropy': '1.177', 'num_tokens': '7479', 'mean_token_accuracy': '0.6562', 'epoch': '0.3556'}
# {'loss': '2.066', 'grad_norm': '5.105', 'learning_rate': '8.83e-06', 'entropy': '1.199', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.6793', 'epoch': '0.7111'}
#  33% 10/30 [05:38<11:14, 33.73s/it]

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
